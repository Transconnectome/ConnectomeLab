# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('NIH_loss_epoch100_0730.csv')

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'epoch', 'reconstuct loss', 'regression loss',
#        'r squared'],
#       dtype='object')

# %%
plt.plot(result['epoch'], result['r squared'])
plt.show()

# %%
plt.plot(result['epoch'].iloc[:5], result['r squared'].iloc[:5])
plt.show()

# %%
plt.plot(result['epoch'].iloc[5:], result['r squared'].iloc[5:])
plt.show()

# %%
plt.plot(result['epoch'], result['reconstuct loss'])
plt.plot(result['epoch'], result['regression loss'])
plt.show()

# %%
plt.plot(result['epoch'].iloc[10:], result['reconstuct loss'].iloc[10:])
plt.show()

# %%
plt.plot(result['epoch'].iloc[10:], result['regression loss'].iloc[10:])
plt.show()

# %% [markdown]
# - Test MSE loss: 0.7734804427339289
# - R2 score: -0.0232421271232
